# %% [markdown]
# # Fertilizer Analysis
#
# Analyze fertilizer data and produce validated recommendation rules.

# %%
from pathlib import Path

DATASET_PATH = Path('../datasets/fertilizer/fertilizer.csv')
RULES_PATH = Path('../trained_models/fertilizer_rules/rules.json')
print(f'Dataset: {DATASET_PATH.resolve()}')
print(f'Rules output: {RULES_PATH.resolve()}')
