# %% [markdown]
# # Crop Recommendation
#
# Explore soil and climate features for crop recommendations.

# %%
from pathlib import Path

DATASET_PATH = Path('../datasets/crop_recommendation/crop_recommendation.csv')
MODEL_PATH = Path('../trained_models/crop_model/crop_model.pkl')
print(f'Dataset: {DATASET_PATH.resolve()}')
print(f'Model output: {MODEL_PATH.resolve()}')
