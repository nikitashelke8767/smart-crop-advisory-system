# %% [markdown]
# # Disease Detection
#
# Train and evaluate the plant disease classifier.

# %%
from pathlib import Path

DATASET_DIR = Path('../datasets/plantvillage')
MODEL_DIR = Path('../trained_models/disease_model')
print(f'Dataset: {DATASET_DIR.resolve()}')
print(f'Model output: {MODEL_DIR.resolve()}')
